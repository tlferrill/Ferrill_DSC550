# %% [markdown]
# # Exercise 1.2, Exploring a Pandas Dataframe
# ## Teresa Ferrill, September 14, 2025
#
# Download the Video Game Sales with Ratings dataset from this link: Video Game Sales with Ratings, https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *1.   Load the dataset as a Pandas data frame.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *2. Display the first ten rows of data.*

# %%
# View first 10 rows of the dataframe
dataframe.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *3. Find the dimensions (number of rows and columns) in the data frame. What do these two numbers represent in the context of the data?*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Show dimensions
# 'shape' returns the number of rows and the number of columns
print("Dataframe Dimensions - (number-of-rows, number-of-columns)")
dataframe.shape
# Out:
# Dataframe Dimensions - (number-of-rows, number-of-columns)
# (16719, 16)

# %% [markdown]
# The first number (16719) is the number of rows and the second number (16) is the number of columns.
# Each row represents a single observation/record/data point within the dataset.
# Each column represents a specific attribute/feature/variable for each observation.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *4. Find the top five games by critic score.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# Sort dataframe by critic score (descending to list highest numbers first), show 5 rows
# Added 'ascending=False' for readability - to list the highest Critic_Score first, followed by the next highest value
dataframe.sort_values(by='Critic_Score', ascending=False).head(5)
# Out:
#                           Name Platform  Year_of_Release     Genre  \
# 57         Grand Theft Auto IV      PS3           2008.0    Action
# 5350               SoulCalibur       DC           1999.0  Fighting
# 227   Tony Hawk's Pro Skater 2       PS           2000.0    Sports
# 51         Grand Theft Auto IV     X360           2008.0    Action
# 165         Grand Theft Auto V     XOne           2014.0    Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 57    Take-Two Interactive      4.76      3.69      0.44         1.61
# 5350    Namco Bandai Games      0.00      0.00      0.34         0.00
# 227             Activision      3.05      1.41      0.02         0.20
# 51    Take-Two Interactive      6.76      3.07      0.14         1.03
# 165   Take-Two Interactive      2.81      2.19      0.00         0.47
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *5. Find the number of video games in the data frame in each genre.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Get the count of games in each genre
genre_counts = dataframe['Genre'].value_counts()

# Group by 'Genre' and count the number of games in each genre
genre_counts = dataframe.groupby('Genre').size()

# Sort the results by genre (alphabetically by default) for readability
sorted_genre_counts = genre_counts.sort_index()

print("Number of video games in each genre, sorted by genre:")
print(sorted_genre_counts)
# Out:
# Number of video games in each genre, sorted by genre:
# Genre
# Action          3370
# Adventure       1303
# Fighting         849
# Misc            1750
# Platform         888
# Puzzle           580
# Racing          1249
# Role-Playing    1500
# Shooter         1323
# Simulation       874
# Sports          2348
# Strategy         683
# dtype: int64

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *6. Find the first five games in the data frame on the SNES platform.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Filter for SNES platform games
snes_games = dataframe[dataframe['Platform'] == 'SNES']

# Print first five games in the SNES dataframe
snes_games.head(5)
# Out:
#                                      Name Platform  Year_of_Release     Genre  \
# 18                      Super Mario World     SNES           1990.0  Platform
# 56                  Super Mario All-Stars     SNES           1993.0  Platform
# 71                    Donkey Kong Country     SNES           1994.0  Platform
# 76                       Super Mario Kart     SNES           1992.0    Racing
# 137  Street Fighter II: The World Warrior     SNES           1992.0  Fighting
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 18   Nintendo     12.78      3.75      3.54         0.55         20.61
# 56   Nintendo      5.99      2.15      2.12         0.29         10.55
# 71   Nintendo      4.36      1.71      3.00         0.23          9.30
# 76   Nintendo      3.54      1.24      3.81         0.18          8.76
# 137    Capcom      2.47      0.83      2.87         0.12          6.30
#
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *7. Find the five publishers with the highest total global sales. Note: You will need to calculate the total global sales for each publisher to do this.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Calculate total global sales for each publisher
publisher_sales = dataframe.groupby('Publisher')['Global_Sales'].sum()

# Sort in descending order and get the top 5
top_5_publishers = publisher_sales.sort_values(ascending=False).head(5)

print("Top 5 publishers with the highest total global sales:")
print(top_5_publishers)
# Out:
# Top 5 publishers with the highest total global sales:
# Publisher
# Nintendo                       1788.81
# Electronic Arts                1116.96
# Activision                      731.16
# Sony Computer Entertainment     606.48
# Ubisoft                         471.61
# Name: Global_Sales, dtype: float64

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *8.Create a new column in the data frame that calculates the percentage of global sales from North America. Display the first five rows of the new data frame.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Create a new column that includes 
dataframe['NA_Percentage'] = ((dataframe['NA_Sales'] / dataframe['Global_Sales']) * 100)
dataframe.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *9. Find the number NaN entries (missing data values) in each column.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Count the number of missing (null or NaN) values in each column of the DataFrame
# Print the results
print(dataframe.isnull().sum())
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------
# *10. Try to calculate the median user score of all the video games. You will likely run into an error because some of the user score entries are a non-numerical string that cannot be converted to a float. Find and replace this string with NaN and then calculate the median. Then, replace all NaN entries in the user score column with the median value.*

# %%
# Load pandas Library
import pandas as pd

# Load Data
# CSV file located at root folder for this notebook
dataframe = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv') 

# Print selected rows from the dataset to include rows with numbers, letters, and null values
# Reivew of the CSV file shows the #119 (Zumba Fitness) row has 'tbd' for the User_Score 
#   while #1 and #201 (Super Mario Bros.) rows have null values
dataframe[dataframe['Name'].isin(['Zumba Fitness','Super Mario Bros.'])]
# Out:
#                    Name Platform  Year_of_Release     Genre  Publisher  \
# 1     Super Mario Bros.      NES           1985.0  Platform   Nintendo
# 119       Zumba Fitness      Wii           2010.0    Sports  505 Games
# 201   Super Mario Bros.       GB           1999.0  Platform   Nintendo
# 669       Zumba Fitness     X360           2010.0    Sports  505 Games
# 3516      Zumba Fitness      PS3           2010.0    Sports  505 Games
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1        29.08      3.58      6.81         0.77         40.24           NaN
# 119       3.45      2.59      0.00         0.66          6.71           NaN
# 201       3.40      1.30      0.15         0.22          5.07           NaN
# 669       1.74      0.45      0.00         0.18          2.37          42.0
# 3516      0.28      0.21      0.00         0.08          0.57           NaN
#
#       Critic_Count User_Score  User_Count                 Developer Rating
# ...

# %%
# Convert the User_Score column type to numeric
# Handle any conversion errors by coercion (errors='coerce'), which replaces the non-numeric value with NaN
dataframe['User_Score'] = pd.to_numeric(dataframe['User_Score'], errors='coerce')

# Calculate the median of the User_Score column
median_user_score = dataframe['User_Score'].median()

# Print out the median value
print("Median_User_Score value")
print(median_user_score)
# Out:
# Median_User_Score value
# 7.5

# %%
# Print selected dataframe rows - the 'tbd' value has been replaced with a NaN value
print("Dataframe with NaN for non-numeric User_Score values")
dataframe[dataframe['Name'].isin(['Zumba Fitness','Super Mario Bros.'])]
# Out:
# Dataframe with NaN for non-numeric User_Score values
#                    Name Platform  Year_of_Release     Genre  Publisher  \
# 1     Super Mario Bros.      NES           1985.0  Platform   Nintendo
# 119       Zumba Fitness      Wii           2010.0    Sports  505 Games
# 201   Super Mario Bros.       GB           1999.0  Platform   Nintendo
# 669       Zumba Fitness     X360           2010.0    Sports  505 Games
# 3516      Zumba Fitness      PS3           2010.0    Sports  505 Games
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1        29.08      3.58      6.81         0.77         40.24           NaN
# 119       3.45      2.59      0.00         0.66          6.71           NaN
# 201       3.40      1.30      0.15         0.22          5.07           NaN
# 669       1.74      0.45      0.00         0.18          2.37          42.0
# 3516      0.28      0.21      0.00         0.08          0.57           NaN
#
# ...

# %%
# Replace NaN entries in User_Score with the calculated Median_User_Score value
dataframe['User_Score'] = dataframe['User_Score'].fillna(median_user_score)

# Print selected rows - the NaN values are replaced with the median_user_score value
print("Dataframe with NaN values replaced with median_user_score")
dataframe[dataframe['Name'].isin(['Zumba Fitness','Super Mario Bros.'])]
# Out:
# Dataframe with NaN values replaced with median_user_score
#                    Name Platform  Year_of_Release     Genre  Publisher  \
# 1     Super Mario Bros.      NES           1985.0  Platform   Nintendo
# 119       Zumba Fitness      Wii           2010.0    Sports  505 Games
# 201   Super Mario Bros.       GB           1999.0  Platform   Nintendo
# 669       Zumba Fitness     X360           2010.0    Sports  505 Games
# 3516      Zumba Fitness      PS3           2010.0    Sports  505 Games
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 1        29.08      3.58      6.81         0.77         40.24           NaN
# 119       3.45      2.59      0.00         0.66          6.71           NaN
# 201       3.40      1.30      0.15         0.22          5.07           NaN
# 669       1.74      0.45      0.00         0.18          2.37          42.0
# 3516      0.28      0.21      0.00         0.08          0.57           NaN
#
# ...
